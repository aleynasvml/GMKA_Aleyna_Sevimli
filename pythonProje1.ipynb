# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %%
url1 = 'https://www.isyatirim.com.tr/tr-tr/analiz/hisse/Sayfalar/Temel-Degerler-Ve-Oranlar.aspx?endeks=01#page-1 '
response1 = requests.get(url1)

# %%
soup1 = bs(response1.text,'html.parser')
table1 = soup1.find('table',{ 'data-csvname':'temelozet'})

# %%
temelozet = pd.read_html(str(table1))
temelozet = pd.DataFrame(temelozet[0])

# %%
url2 = 'https://www.isyatirim.com.tr/tr-tr/analiz/hisse/Sayfalar/Temel-Degerler-Ve-Oranlar.aspx?endeks=01#page-6 '
response2 = requests.get(url2)

soup2 = bs(response2.text,'html.parser')
table2 = soup2.find('table',{ 'data-csvname':'temelperformans'})
hissePerf = pd.read_html(str(table2))
hissePerf = pd.DataFrame(hissePerf[0]) 
hissePerf = hissePerf[['Yıl İçi Getiri (%)']]
#Performans dosyasından sadece yıl içi getiri yüzdesi ile karşılaştırmak istedik

temelozet
# Out:
#       Kod              Hisse Adı               Sektör Kapanış (TL)  \
# 0   AEFES           Anadolu Efes    Meşrubat / İçecek         6190
# 1   AGHOL  Anadolu Grubu Holding           Holdingler         9545
# 2   AKBNK                 Akbank           Bankacılık         1577
# 3   AKFGY              Akfen GYO                  GYO          322
# 4    AKSA                   Aksa  Endüstriyel Tekstil         5910
# ..    ...                    ...                  ...          ...
# 95  VESBE      Vestel Beyaz Esya    Dayanıklı Tüketim         1036
# 96  VESTL      Vestel Elektronik    Dayanıklı Tüketim         4190
# 97  YKBNK     Yapı Kredi Bankası           Bankacılık          948
# 98  YYLGD        Yayla Agro Gıda                 Gıda         2268
# 99  ZOREN           Zorlu Enerji             Elektrik          457
#
#    Piyasa Değeri (mn TL) Piyasa Değeri (mn $)  Halka Açıklık Oranı (%)  \
# 0               36.651,3              1.859,0                      329
# 1               23.245,4              1.179,0                      358
# 2               82.004,0              4.159,4                      518
# 3                4.186,0                 2123                      445
# 4               19.133,6                 9705                      353
# ..                   ...                  ...                      ...
# 95              16.576,0                 8408                      193
# 96              14.055,6                 7129                      399
# 97              80.078,0              4.061,7                      320
# 98              10.718,6                 5437                      150
# 99              11.425,0                 5795                      291
#
#    Sermaye (mn TL)
# 0             5921
# 1             2435
# 2          5.200,0
# 3          1.300,0
# 4             3238
# ..             ...
# 95         1.600,0
# 96            3355
# 97         8.447,1
# 98            4726
# 99         2.500,0
#
# [100 rows x 8 columns]

# %%
#Yıl içi getiri sütununu temel ozet tablosuna ekledik.
extracted_col = hissePerf["Yıl İçi Getiri (%)"]
temelozet = temelozet.join(extracted_col)

# %%
#Değerlerdeki virgül sorununu çözmek için değerler üzerinde işlem yaptık.
temelozet['Halka Açıklık Oranı (%)'] = pd.to_numeric(temelozet['Halka Açıklık Oranı (%)'])
temelozet['Halka Açıklık Oranı (%)'] = temelozet['Halka Açıklık Oranı (%)']
temelozet['Yıl İçi Getiri (%)'] = temelozet['Yıl İçi Getiri (%)'].apply(lambda x: x/100 )

# %%
# Sektörlere göre gruplandırma ve ortalama hesaplama
ortalama_halka_aciklik = temelozet.groupby('Sektör')['Halka Açıklık Oranı (%)'].mean()

# Gruplanmış verileri yeni bir veri çerçevesine dönüştürme
ortalama_df = pd.DataFrame({'Sektör': ortalama_halka_aciklik.index, 'Ortalama Halka Açıklık Oranı (%)': ortalama_halka_aciklik})

# Yeni veri çerçevesini kullanarak bar grafiği oluşturma
fig_2 = px.bar(
    y=ortalama_df['Sektör'],
    x=ortalama_df['Ortalama Halka Açıklık Oranı (%)'].apply(lambda x: x/10),
    width=1000,
    height=500,
    title='Sektör/Ortalama Halka Açıklık Oranı',
    labels={'x': 'Ortalama Halka Açıklık Oranı (%)', 'y': 'Sektör'},
    color=ortalama_df['Sektör'],
    color_discrete_sequence=px.colors.qualitative.Dark24,
    orientation='h'  # Çubuk grafiğini yatay olarak çizme
)
fig_2.update_layout(
    font=dict(size=16) 
)
fig_2.update_layout(yaxis={'categoryorder':'total ascending'}, height=800)
fig_2.update_xaxes(tickfont=dict(size=16)) 
fig_2.update_yaxes(tickfont=dict(size=16)) 

fig_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7061cf22-072f-46f4-b98f-fc9ac243c688" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7061cf22-072f-46f4-b98f-fc9ac243c688")) {                    Plotly.newPlot(                        "7061cf22-072f-46f4-b98f-fc9ac243c688",                        [{"alignmentgroup":"True","hovertemplate":"color=Bankac\u0131l\u0131k<br>Ortalama Halka A\u00e7\u0131kl\u0131k Oran\u0131 (%)=%{x}<br>Sekt\u00f6r=%{y}<extra></extra>","legendgroup":"Bankac\u0131l\u0131k","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"Bankac\u0131l\u0131k","offsetgroup":"Bankac\u0131l\u0131k","orientation":"h","showlegend":true,"textposition":"auto","x":[29.944444444444446],"xaxis":"x","y":["Bankac\u0131l\u0131k"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Cam<br>Ortalama Halka A\u00e7\u0131kl\u0131k Oran\u0131 (%)=%{x}<br>Sekt\u00f6r=%{y}<extra></extra>","legendgroup":"Cam","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"Cam","offsetgroup":"Cam","orientation":"h","showlegend":true,"textposition":"auto","x":[48.9],"xaxis":"x","y":["Cam"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Dayan\u0131kl\u0131 T\u00fcketim<br>Ortalama Halka A\u00e7\u0131kl\u0131k Oran\u0131 (%)=%{x}<br>Sekt\u00f6r=%{y}<extra></extra>","legendgroup":"Dayan\u0131kl\u0131 T\u00fcketim","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"Dayan\u0131kl\u0131 T\u00fcketim","offsetgroup":"Dayan\u0131kl\u0131 T\u00fcketim","orientation":"h","showlegend":true,"textposition":"auto","x":[24.6],"xaxis":"x","y":["Dayan\u0131kl\u0131 T\u00fcketim"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Demir-\u00c7elik D\u00f6k\u00fcm<br>Ortalama Halka A\u00e7\u0131kl\u0131k Oran\u0131 (%)=%{x}<br>Sekt\u00f6r=%{y}<extra></extra>","legendgroup":"Demir-\u00c7elik D\u00f6k\u00fcm","marker":{"color":"#FB0D0D","pattern":{"shape":""}},"name":"Demir-\u00c7elik D\u00f6k\u00fcm","offsetgroup":"Demir-\u00c7elik D\u00f6k\u00fcm","orientation":"h","showlegend":true,"textposition":"auto","x":[44.1],"xaxis":"x","y":["Demir-\u00c7elik D\u00f6k\u00fcm"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Demir-\u00c7elik Temel<br>Ortalama Halka A\u00e7\u0131kl\u0131k Oran\u0131 (%)=%{x}<br>Sekt\u00f6r=%{y}<extra></extra>","legendgroup":"Demir-\u00c7elik Temel","marker":{"color":"#DA16FF","pattern":{"shape":""}},"name":"Demir-\u00c7elik Temel","offsetgroup":"Demir-\u00c7elik Temel","orientation":"h","showlegend":true,"textposition":"auto","x":[39.983333333333334],"xaxis":"x","y":["Demir-\u00c7elik Temel"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Elektrik<br>Ortalama Halka A\u00e7\u0131kl\u0131k Oran\u0131 (%)=%{x}<br>Sekt\u00f6r=%{y}<extra></extra>","legendgroup":"Elektrik","marker":{"color":"#222A2A","pattern":{"shape":""}},"name":"Elektrik","offsetgroup":"Elektrik","orientation":"h","showlegend":true,"textposition":"auto","x":[30.338461538461537],"xaxis":"x","y":["Elektrik"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=End\u00fcstriyel Tekstil<br>Ortalama Halka A\u00e7\u0131kl\u0131k Oran\u0131 (%)=%{x}<br>Sekt\u00f6r=%{y}<extra></extra>","legendgroup":"End\u00fcstriyel Tekstil","marker":{"color":"#B68100","pattern":{"shape":""}},"name":"End\u00fcstriyel Tekstil","offsetgroup":"End\u00fcstriyel Tekstil","orientation":"h","showlegend":true,"textposition":"auto","x":[28.93333333333333],"xaxis":"x","y":["End\u00fcstriyel Tekstil"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=GYO<br>Ortalama Halka A\u00e7\u0131kl\u0131k Oran\u0131 (%)=%{x}<br>Sekt\u00f6r=%{y}<extra></extra>","legendgroup":"GYO","marker":{"colo ...

# %%
# Sektörlere göre gruplandırma ve ortalama hesaplama
ortalama_yil_ici_getiri = temelozet.groupby('Sektör')['Yıl İçi Getiri (%)'].mean()

# Gruplanmış verileri yeni bir veri çerçevesine dönüştürme
ortalama_df = pd.DataFrame({'Sektör': ortalama_yil_ici_getiri.index, 'Ortalama Yıl İçi Getiri (%)': ortalama_yil_ici_getiri})

# Yeni veri çerçevesini kullanarak bar grafiği oluşturma
fig_3 = px.bar(
    y=ortalama_df['Sektör'],
    x=ortalama_df['Ortalama Yıl İçi Getiri (%)'],
    width=1000,
    height=500,
    title='Sektör/Ortalama Yıl İçi Getiri (%)(17.05.2023)',
    color=ortalama_df['Ortalama Yıl İçi Getiri (%)'].apply(lambda x: 'pozitif' if x >= 0 else 'negatif'),
    color_discrete_map={'pozitif':'green', 'negatif':'red'},
    labels={'x': 'Ortalama Yıl İçi Getiri (%)', 'y': 'Sektör'},
    orientation='h'
)
fig_3.update_layout(
    font=dict(size=16) 
)
fig_3.update_layout(yaxis={'categoryorder':'total ascending'}, height=800)
fig_3.update_xaxes(tickfont=dict(size=16)) 
fig_3.update_yaxes(tickfont=dict(size=16)) 

fig_3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6f1de8e8-0790-4950-836d-9d59d81e0fb2" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f1de8e8-0790-4950-836d-9d59d81e0fb2")) {                    Plotly.newPlot(                        "6f1de8e8-0790-4950-836d-9d59d81e0fb2",                        [{"alignmentgroup":"True","hovertemplate":"color=negatif<br>Ortalama Y\u0131l \u0130\u00e7i Getiri (%)=%{x}<br>Sekt\u00f6r=%{y}<extra></extra>","legendgroup":"negatif","marker":{"color":"red","pattern":{"shape":""}},"name":"negatif","offsetgroup":"negatif","orientation":"h","showlegend":true,"textposition":"auto","x":[-15.21888888888889,-11.23,-27.66333333333333,-37.155,-22.233333333333334,-30.957692307692305,-26.75,-33.92166666666667,-42.268,-13.089999999999998,-22.711,-35.14,-28.66,-18.634999999999998,-31.1,-0.06500000000000128,-20.355,-31.2,-20.543333333333333,-20.85,-35.72,-31.00333333333333,-16.34,-29.165,-32.894999999999996],"xaxis":"x","y":["Bankac\u0131l\u0131k","Cam","Dayan\u0131kl\u0131 T\u00fcketim","Demir-\u00c7elik D\u00f6k\u00fcm","Demir-\u00c7elik Temel","Elektrik","End\u00fcstriyel Tekstil","GYO","G\u0131da","Havayollar\u0131 ve Hizm.","Holdingler","Kimyasal \u00dcr\u00fcn","Madencilik","Otomotiv","Otomotiv Par\u00e7as\u0131","Perakande - Ticaret","Petrol","Savunma","Sa\u011fl\u0131k ve \u0130la\u00e7","Sigorta","Spor","Tar\u0131m Kimyasallar\u0131","Tekstil Entegre","\u0130leti\u015fim","\u0130n\u015faat- Taahh\u00fct"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=pozitif<br>Ortalama Y\u0131l \u0130\u00e7i Getiri (%)=%{x}<br>Sekt\u00f6r=%{y}<extra></extra>","legendgroup":"pozitif","marker":{"color":"green","pattern":{"shape":""}},"name":"pozitif","offsetgroup":"pozitif","orientation":"h","showlegend":true,"textposition":"auto","x":[3.7800000000000002,1.259999999999998],"xaxis":"x","y":["Me\u015frubat / \u0130\u00e7ecek","\u00c7imento"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111 ...

# %%
# Virgül ve nokta işaretlerini kaldırma
temelozet['Piyasa Değeri (mn TL)'] = temelozet['Piyasa Değeri (mn TL)'].str.replace(',', '').str.replace('.', '')
# Sayısal değere dönüştürme
temelozet['Piyasa Değeri (mn TL)'] = pd.to_numeric(temelozet['Piyasa Değeri (mn TL)'])
temelozet['Piyasa Değeri (TL)'] = temelozet['Piyasa Değeri (mn TL)'] * 1000000

import plotly.express as px

sektorel_ortalama = temelozet.groupby('Sektör')['Piyasa Değeri (TL)'].mean().reset_index()
genel_ortalama = sektorel_ortalama['Piyasa Değeri (TL)'].mean()

fig = px.bar(
    sektorel_ortalama,
    y='Sektör',
    x='Piyasa Değeri (TL)',
    color=sektorel_ortalama['Piyasa Değeri (TL)'].apply(lambda x: 'Alt Ortalama' if x < genel_ortalama else 'Üst Ortalama'),
    color_discrete_map={'Alt Ortalama': 'lightgreen', 'Üst Ortalama': 'green'},
    title='Sektörlere Göre Ortalama Piyasa Değeri',
    orientation='h'
)
fig.update_layout(yaxis={'categoryorder':'total ascending'}, height=800)
fig.update_layout(yaxis={'categoryorder': 'total ascending'})
fig.show()
# Out:
# <ipython-input-192-b5d389a74f44>:2: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4abf0418-9a64-4ba3-b950-c7548cbfe3e4" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4abf0418-9a64-4ba3-b950-c7548cbfe3e4")) {                    Plotly.newPlot(                        "4abf0418-9a64-4ba3-b950-c7548cbfe3e4",                        [{"alignmentgroup":"True","hovertemplate":"color=\u00dcst Ortalama<br>Piyasa De\u011feri (TL)=%{x}<br>Sekt\u00f6r=%{y}<extra></extra>","legendgroup":"\u00dcst Ortalama","marker":{"color":"green","pattern":{"shape":""}},"name":"\u00dcst Ortalama","offsetgroup":"\u00dcst Ortalama","orientation":"h","showlegend":true,"textposition":"auto","x":[641037000000.0,1167085000000.0,868874333333.3334,856790666666.6666,485322000000.0,486292000000.0,804965000000.0,974928000000.0,479315666666.6667,597760000000.0,778950000000.0],"xaxis":"x","y":["Bankac\u0131l\u0131k","Cam","End\u00fcstriyel Tekstil","Havayollar\u0131 ve Hizm.","Me\u015frubat / \u0130\u00e7ecek","Otomotiv","Petrol","Savunma","Tar\u0131m Kimyasallar\u0131","\u0130leti\u015fim","\u0130n\u015faat- Taahh\u00fct"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Alt Ortalama<br>Piyasa De\u011feri (TL)=%{x}<br>Sekt\u00f6r=%{y}<extra></extra>","legendgroup":"Alt Ortalama","marker":{"color":"lightgreen","pattern":{"shape":""}},"name":"Alt Ortalama","offsetgroup":"Alt Ortalama","orientation":"h","showlegend":true,"textposition":"auto","x":[311919000000.0,42690000000.0,387164333333.3333,155360000000.0,84416166666.66667,72914000000.0,403549800000.0,63456500000.0,379175500000.0,132426000000.0,362045250000.0,164732666666.66666,115107000000.0,46382000000.0,105471000000.0,175984250000.0],"xaxis":"x","y":["Dayan\u0131kl\u0131 T\u00fcketim","Demir-\u00c7elik D\u00f6k\u00fcm","Demir-\u00c7elik Temel","Elektrik","GYO","G\u0131da","Holdingler","Kimyasal \u00dcr\u00fcn","Madencilik","Otomotiv Par\u00e7as\u0131","Perakande - Ticaret","Sa\u011fl\u0131k ve \u0130la\u00e7","Sigorta","Spor","Tekstil Entegre","\u00c7imento"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"t ...

# %%
piyasa_degeri = temelozet['Piyasa Değeri (mn TL)']
temelozet['Piyasa Değeri (TL)'] = temelozet['Piyasa Değeri (TL)'].apply(lambda x: ''.join(filter(str.isdigit, str(x)))).astype(float)
temelozet['Piyasa Değeri (TL)'] = temelozet['Piyasa Değeri (mn TL)'] * 1000000
sektorel_ortalama = temelozet.groupby('Sektör')['Piyasa Değeri (TL)'].mean()


# Veri çerçevesini Sektör'e göre sıralama
sektorel_ortalama = sektorel_ortalama.sort_values(ascending=False).reset_index()

# Genel ortalama değerini hesaplama
genel_ortalama = sektorel_ortalama['Piyasa Değeri (TL)'].mean()

# Yatay çubuk grafik oluşturma
fig_4 = px.bar(
    sektorel_ortalama,
    y='Sektör',
    x='Piyasa Değeri (TL)',
    color=sektorel_ortalama['Piyasa Değeri (TL)'].apply(lambda x: 'Alt Ortalama' if x < genel_ortalama else 'Üst Ortalama'),
    color_discrete_map={'Alt Ortalama': 'lightgreen', 'Üst Ortalama': 'green'},
    title='Sektörel Ortalama Piyasa Değeri',
    orientation='h'
)
fig_4.update_layout(yaxis={'categoryorder':'total ascending'}, height=800)  # Grafik boyutunu ayarlayın
fig_4.update_yaxes(tickfont=dict(size=12))  # Sektör etiketlerinin yazı boyutunu ayarlayın
fig_4
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2dca86db-8c3f-4cc2-af74-589b2b29b477" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dca86db-8c3f-4cc2-af74-589b2b29b477")) {                    Plotly.newPlot(                        "2dca86db-8c3f-4cc2-af74-589b2b29b477",                        [{"alignmentgroup":"True","hovertemplate":"color=\u00dcst Ortalama<br>Piyasa De\u011feri (TL)=%{x}<br>Sekt\u00f6r=%{y}<extra></extra>","legendgroup":"\u00dcst Ortalama","marker":{"color":"green","pattern":{"shape":""}},"name":"\u00dcst Ortalama","offsetgroup":"\u00dcst Ortalama","orientation":"h","showlegend":true,"textposition":"auto","x":[1167085000000.0,974928000000.0,868874333333.3334,856790666666.6666,804965000000.0,778950000000.0,641037000000.0,597760000000.0,486292000000.0,485322000000.0,479315666666.6667],"xaxis":"x","y":["Cam","Savunma","End\u00fcstriyel Tekstil","Havayollar\u0131 ve Hizm.","Petrol","\u0130n\u015faat- Taahh\u00fct","Bankac\u0131l\u0131k","\u0130leti\u015fim","Otomotiv","Me\u015frubat / \u0130\u00e7ecek","Tar\u0131m Kimyasallar\u0131"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Alt Ortalama<br>Piyasa De\u011feri (TL)=%{x}<br>Sekt\u00f6r=%{y}<extra></extra>","legendgroup":"Alt Ortalama","marker":{"color":"lightgreen","pattern":{"shape":""}},"name":"Alt Ortalama","offsetgroup":"Alt Ortalama","orientation":"h","showlegend":true,"textposition":"auto","x":[403549800000.0,387164333333.3333,379175500000.0,362045250000.0,311919000000.0,175984250000.0,164732666666.66666,155360000000.0,132426000000.0,115107000000.0,105471000000.0,84416166666.66667,72914000000.0,63456500000.0,46382000000.0,42690000000.0],"xaxis":"x","y":["Holdingler","Demir-\u00c7elik Temel","Madencilik","Perakande - Ticaret","Dayan\u0131kl\u0131 T\u00fcketim","\u00c7imento","Sa\u011fl\u0131k ve \u0130la\u00e7","Elektrik","Otomotiv Par\u00e7as\u0131","Sigorta","Tekstil Entegre","GYO","G\u0131da","Kimyasal \u00dcr\u00fcn","Spor","Demir-\u00c7elik D\u00f6k\u00fcm"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"t ...

# %%
sirketler = ['BIMAS.IS', 'MGROS.IS', 'SOKM.IS', 'TUKAS.IS', 'ULUUN.IS', 'XU100.IS']
veriler = pd.DataFrame()
for sirket in sirketler:
    data = yf.download(sirket, start='2021-01-01', end='2021-12-31')
    data = data[['Adj Close']]
    data.columns = [sirket]
    if veriler.empty:
        veriler = data
    else:
        veriler = veriler.join(data)

veriler
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#              BIMAS.IS   MGROS.IS    SOKM.IS  TUKAS.IS  ULUUN.IS     XU100.IS
# Date
# 2021-01-04  69.055031  44.560001  12.846131  5.333333  4.692737  1495.400024
# 2021-01-05  67.854462  43.980000  13.034028  5.294444  4.772887  1489.599976
# 2021-01-06  67.943398  44.139999  12.895577  5.316666  4.857043  1505.400024
# 2021-01-07  68.476974  43.820000  12.935135  5.305555  4.897118  1522.199951
# 2021-01-08  69.618263  44.540001  13.835056  5.400000  4.885096  1540.599976
# ...               ...        ...        ...       ...       ...          ...
# 2021-12-24  63.502342  39.340000  13.020000  4.083333  6.013757  1891.300049
# 2021-12-27  62.045868  38.779999  13.390000  4.038888  5.868848  1897.099976
# 2021-12-28  60.783585  37.220001  13.120000  3.966666  5.696767  1850.500000
# 2021-12-29  61.851673  37.880001  13.130000  4.066666  6.203951  1895.500000
# 2021-12-30  59.861156  37.060001  12.730000  4.072222  6.122440  1863.699951
#
# [248 rows x 6 columns]

# %%
norm1 = veriler.iloc[0,0]
norm2 = veriler.iloc[0,1]
norm3 = veriler.iloc[0,2]
norm4 = veriler.iloc[0,3]
norm5 = veriler.iloc[0,4]
norm6 = veriler.iloc[0,5]

veriler['Normalize BIMAS.IS'] =veriler[['BIMAS.IS']]/norm1
veriler['Normalize MGROS.IS'] =veriler[['MGROS.IS']]/norm2
veriler['Normalize SOKM.IS'] =veriler[['SOKM.IS']]/norm3
veriler['Normalize TUKAS.IS'] =veriler[['TUKAS.IS']]/norm4
veriler['Normalize ULUUN.IS'] =veriler[['ULUUN.IS']]/norm5
veriler['Normalize XU100.IS'] =veriler[['XU100.IS']]/norm6

normalize_veriler = veriler[['Normalize BIMAS.IS', 'Normalize MGROS.IS', 'Normalize SOKM.IS', 'Normalize TUKAS.IS', 'Normalize ULUUN.IS', 'Normalize XU100.IS']]
normalize_veriler
# Out:
#             Normalize BIMAS.IS  Normalize MGROS.IS  Normalize SOKM.IS  \
# Date
# 2021-01-04            1.000000            1.000000           1.000000
# 2021-01-05            0.982614            0.986984           1.014627
# 2021-01-06            0.983902            0.990574           1.003849
# 2021-01-07            0.991629            0.983393           1.006928
# 2021-01-08            1.008156            0.999551           1.076982
# ...                        ...                 ...                ...
# 2021-12-24            0.919590            0.882855           1.013535
# 2021-12-27            0.898499            0.870287           1.042337
# 2021-12-28            0.880219            0.835278           1.021319
# 2021-12-29            0.895687            0.850090           1.022098
# 2021-12-30            0.866862            0.831688           0.990960
#
#             Normalize TUKAS.IS  Normalize ULUUN.IS  Normalize XU100.IS
# Date
# 2021-01-04            1.000000            1.000000            1.000000
# 2021-01-05            0.992708            1.017080            0.996121
# 2021-01-06            0.996875            1.035013            1.006687
# 2021-01-07            0.994792            1.043553            1.017922
# 2021-01-08            1.012500            1.040991            1.030226
# ...                        ...                 ...                 ...
# 2021-12-24            0.765625            1.281503            1.264745
# 2021-12-27            0.757292            1.250624            1.268624
# 2021-12-28            0.743750            1.213954            1.237462
# 2021-12-29            0.762500            1.322033            1.267554
# 2021-12-30            0.763542            1.304663            1.246289
#
# [248 rows x 6 columns]

# %%
import plotly.express as px

fig = px.line(normalize_veriler, x=normalize_veriler.index, y=normalize_veriler.columns)


fig.update_traces(hovertemplate='Tarih: %{x}<br>Normalize Edilmiş Değer: %{y:.2f}')
fig.update_layout(
    xaxis_title='Tarih',
    yaxis_title='Normalize Edilmiş Kapanış Değerleri',
    title='Normalize Edilmiş Kapanış Değerleri Değişimi',
    legend=dict(title='Şirket'),
    width=1000,
    height=500
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1a6e937e-721a-4b33-bb2c-c93ee0d05f06" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a6e937e-721a-4b33-bb2c-c93ee0d05f06")) {                    Plotly.newPlot(                        "1a6e937e-721a-4b33-bb2c-c93ee0d05f06",                        [{"hovertemplate":"Tarih: %{x}<br>Normalize Edilmi\u015f De\u011fer: %{y:.2f}","legendgroup":"Normalize BIMAS.IS","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Normalize BIMAS.IS","showlegend":true,"x":["2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-15T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-11T00:00:00","2021-03-12T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-02T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-14T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-21T00:00:00","2021-04-22T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-05-31T00:00:00","2021-06-01T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-04T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-06-17T00:00:00","2021-06-18T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-23T00:00:00","2021-06-24T00:00:00","2021-06-25T00:00:00","2021-06-28T00:00:00","2021-06-29T00:00:00","2021-06-30T00:00:00","2021-07-01T00:00:00","2021-07-02T00:00:00","2021-07-05T00:00:00","2021-07-06T00:00:00","2021-07-07T00:00:00","2021-07-08T00:00:00","2021-07-09T00:00:00","2021-07-12T00:00:00","2021-07-13T00:00:00","2021-07-14T00:00:00","2021-07-16T00:00:00","2021-07-19T00:00:00","2021-07-26T00:00:00","2021-07-27T00:00:00","2021-07-28T00:00:00","2021-07-29T00:00:00","2021-07-30T00:00:00","2021-08-02T00:00:00","2021-08-03T00:00:00","2021-08-04T00:00:00","2021-08-05T00:00:00","2021-08-0 ...

# %%
import plotly.graph_objects as go

# Son değerleri alın
son_degerler = normalize_veriler.iloc[-1]

# Görselleştirme için figür oluşturun
fig = go.Figure(data=[go.Table(
    header=dict(values=['Şirket', 'Son Değer']),
    cells=dict(values=[son_degerler.index, son_degerler.values.round(2)])
)])

# Görsel boyutunu ayarlayın
fig.update_layout(width=600, height=400)

# Görseli gösterin
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="cc659c26-ce24-4e23-83cb-016f2aa4e674" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc659c26-ce24-4e23-83cb-016f2aa4e674")) {                    Plotly.newPlot(                        "cc659c26-ce24-4e23-83cb-016f2aa4e674",                        [{"cells":{"values":[["Normalize BIMAS.IS","Normalize MGROS.IS","Normalize SOKM.IS","Normalize TUKAS.IS","Normalize ULUUN.IS","Normalize XU100.IS"],[0.87,0.83,0.99,0.76,1.3,1.25]]},"header":{"values":["\u015eirket","Son De\u011fer"]},"type":"table"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fill ...

# %%
normalize_veriler['ay_yıl']=normalize_veriler.index.strftime('%Y-%m')
normalize_veriler
# Out:
# <ipython-input-198-9f28f83b84d9>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Normalize BIMAS.IS  Normalize MGROS.IS  Normalize SOKM.IS  \
# Date
# 2021-01-04            1.000000            1.000000           1.000000
# 2021-01-05            0.982614            0.986984           1.014627
# 2021-01-06            0.983902            0.990574           1.003849
# 2021-01-07            0.991629            0.983393           1.006928
# 2021-01-08            1.008156            0.999551           1.076982
# ...                        ...                 ...                ...
# 2021-12-24            0.919590            0.882855           1.013535
# 2021-12-27            0.898499            0.870287           1.042337
# 2021-12-28            0.880219            0.835278           1.021319
# 2021-12-29            0.895687            0.850090           1.022098
# 2021-12-30            0.866862            0.831688           0.990960
#
#             Normalize TUKAS.IS  Normalize ULUUN.IS  Normalize XU100.IS  \
# Date
# 2021-01-04            1.000000            1.000000            1.000000
# 2021-01-05            0.992708            1.017080            0.996121
# 2021-01-06            0.996875            1.035013            1.006687
# 2021-01-07            0.994792            1.043553            1.017922
# 2021-01-08            1.012500            1.040991            1.030226
# ...                        ...                 ...                 ...
# 2021-12-24            0.765625            1.281503            1.264745
# 2021-12-27            0.757292            1.250624            1.268624
# 2021-12-28            0.743750            1.213954            1.237462
# 2021-12-29            0.762500            1.322033            1.267554
# 2021-12-30            0.763542            1.304663            1.246289
#
#              ay_yıl
# Date
# 2021-01-04  2021-01
# 2021-01-05  2021-01
# 2021-01-06  2021-01
# 2021-01-07  2021-01
# 2021-01-08  2021-01
# ...             ...
# 2021-12-24  2021-12
# 2021-12-27  2021-12
# 2021-12-28  2021-12
# 2021-12-29  2021-12
# 2021-12-30  2021-12
#
# [248 rows x 7 columns]

# %%
aylık_normalize=normalize_veriler.pivot_table(index='ay_yıl',aggfunc='last')
aylık_normalize
# Out:
#          Normalize BIMAS.IS  Normalize MGROS.IS  Normalize SOKM.IS  \
# ay_yıl
# 2021-01            0.951303            0.990574           1.020785
# 2021-02            0.873956            0.876571           0.869900
# 2021-03            0.933453            0.785458           0.903772
# 2021-04            0.859412            0.814632           0.931486
# 2021-05            0.872097            0.777379           0.856813
# 2021-06            0.847550            0.729354           0.903772
# 2021-07            0.864597            0.765260           0.889762
# 2021-08            0.979831            0.781867           0.961379
# 2021-09            0.871415            0.707361           0.918564
# 2021-10            0.847550            0.789946           0.864073
# 2021-11            0.975835            0.956463           1.103834
# 2021-12            0.866862            0.831688           0.990960
#
#          Normalize TUKAS.IS  Normalize ULUUN.IS  Normalize XU100.IS
# ay_yıl
# 2021-01            0.976042            1.522630            0.985355
# 2021-02            0.909375            1.440649            0.983951
# 2021-03            0.826042            1.286934            0.930654
# 2021-04            0.753125            1.098156            0.934733
# 2021-05            0.706250            1.005517            0.949913
# 2021-06            0.710417            0.914808            0.906981
# 2021-07            0.694792            0.970777            0.931456
# 2021-08            0.694792            1.003587            0.984419
# 2021-09            0.702083            1.067276            0.940484
# 2021-10            0.703125            1.007447            1.017788
# 2021-11            0.883333            1.362562            1.210178
# 2021-12            0.763542            1.304663            1.246289

# %%
bist100 = aylık_normalize[['Normalize XU100.IS']].copy()
bist100
# Out:
#          Normalize XU100.IS
# ay_yıl
# 2021-01            0.985355
# 2021-02            0.983951
# 2021-03            0.930654
# 2021-04            0.934733
# 2021-05            0.949913
# 2021-06            0.906981
# 2021-07            0.931456
# 2021-08            0.984419
# 2021-09            0.940484
# 2021-10            1.017788
# 2021-11            1.210178
# 2021-12            1.246289

# %%
aylık_normalize.drop('Normalize XU100.IS', axis=1, inplace=True)
aylık_normalize
# Out:
#          Normalize BIMAS.IS  Normalize MGROS.IS  Normalize SOKM.IS  \
# ay_yıl
# 2021-01            0.951303            0.990574           1.020785
# 2021-02            0.873956            0.876571           0.869900
# 2021-03            0.933453            0.785458           0.903772
# 2021-04            0.859412            0.814632           0.931486
# 2021-05            0.872097            0.777379           0.856813
# 2021-06            0.847550            0.729354           0.903772
# 2021-07            0.864597            0.765260           0.889762
# 2021-08            0.979831            0.781867           0.961379
# 2021-09            0.871415            0.707361           0.918564
# 2021-10            0.847550            0.789946           0.864073
# 2021-11            0.975835            0.956463           1.103834
# 2021-12            0.866862            0.831688           0.990960
#
#          Normalize TUKAS.IS  Normalize ULUUN.IS
# ay_yıl
# 2021-01            0.976042            1.522630
# 2021-02            0.909375            1.440649
# 2021-03            0.826042            1.286934
# 2021-04            0.753125            1.098156
# 2021-05            0.706250            1.005517
# 2021-06            0.710417            0.914808
# 2021-07            0.694792            0.970777
# 2021-08            0.694792            1.003587
# 2021-09            0.702083            1.067276
# 2021-10            0.703125            1.007447
# 2021-11            0.883333            1.362562
# 2021-12            0.763542            1.304663

# %%
aylık_normalize['BIST5 Normalizasyon'] = aylık_normalize.mean(axis=1)
aylık_normalize
# Out:
#          Normalize BIMAS.IS  Normalize MGROS.IS  Normalize SOKM.IS  \
# ay_yıl
# 2021-01            0.951303            0.990574           1.020785
# 2021-02            0.873956            0.876571           0.869900
# 2021-03            0.933453            0.785458           0.903772
# 2021-04            0.859412            0.814632           0.931486
# 2021-05            0.872097            0.777379           0.856813
# 2021-06            0.847550            0.729354           0.903772
# 2021-07            0.864597            0.765260           0.889762
# 2021-08            0.979831            0.781867           0.961379
# 2021-09            0.871415            0.707361           0.918564
# 2021-10            0.847550            0.789946           0.864073
# 2021-11            0.975835            0.956463           1.103834
# 2021-12            0.866862            0.831688           0.990960
#
#          Normalize TUKAS.IS  Normalize ULUUN.IS  BIST5 Normalizasyon
# ay_yıl
# 2021-01            0.976042            1.522630             1.092267
# 2021-02            0.909375            1.440649             0.994090
# 2021-03            0.826042            1.286934             0.947132
# 2021-04            0.753125            1.098156             0.891362
# 2021-05            0.706250            1.005517             0.843611
# 2021-06            0.710417            0.914808             0.821180
# 2021-07            0.694792            0.970777             0.837038
# 2021-08            0.694792            1.003587             0.884291
# 2021-09            0.702083            1.067276             0.853340
# 2021-10            0.703125            1.007447             0.842428
# 2021-11            0.883333            1.362562             1.056406
# 2021-12            0.763542            1.304663             0.951543

# %%
aylık_normalize=aylık_normalize[['BIST5 Normalizasyon']]
aylık_normalize
# Out:
#          BIST5 Normalizasyon
# ay_yıl
# 2021-01             1.092267
# 2021-02             0.994090
# 2021-03             0.947132
# 2021-04             0.891362
# 2021-05             0.843611
# 2021-06             0.821180
# 2021-07             0.837038
# 2021-08             0.884291
# 2021-09             0.853340
# 2021-10             0.842428
# 2021-11             1.056406
# 2021-12             0.951543

# %%
aylık_normalize=aylık_normalize.merge(bist100,left_index=True,right_index=True)
aylık_normalize
# Out:
#          BIST5 Normalizasyon  Normalize XU100.IS
# ay_yıl
# 2021-01             1.092267            0.985355
# 2021-02             0.994090            0.983951
# 2021-03             0.947132            0.930654
# 2021-04             0.891362            0.934733
# 2021-05             0.843611            0.949913
# 2021-06             0.821180            0.906981
# 2021-07             0.837038            0.931456
# 2021-08             0.884291            0.984419
# 2021-09             0.853340            0.940484
# 2021-10             0.842428            1.017788
# 2021-11             1.056406            1.210178
# 2021-12             0.951543            1.246289

# %%
graf= px.line(aylık_normalize,y=['BIST5 Normalizasyon','Normalize XU100.IS'])
# Grafiğin görüntüsünü ayarlama
graf.update_layout(
    title="BIST5 vs. BIST100",
    xaxis_title="Tarih",
    yaxis_title="Normalize edilmiş değerler",
    width=1700,
    height=800,
    showlegend=True
)
# X eksenini ay formatında gösterme
graf.update_xaxes(
    dtick="M1",
    tickformat="%b\n%Y"
)

# Grafiği gösterme
graf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2c26f13e-946b-4a8d-a7dd-54cd86333816" class="plotly-graph-div" style="height:800px; width:1700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c26f13e-946b-4a8d-a7dd-54cd86333816")) {                    Plotly.newPlot(                        "2c26f13e-946b-4a8d-a7dd-54cd86333816",                        [{"hovertemplate":"variable=BIST5 Normalizasyon<br>ay_y\u0131l=%{x}<br>value=%{y}<extra></extra>","legendgroup":"BIST5 Normalizasyon","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BIST5 Normalizasyon","orientation":"v","showlegend":true,"x":["2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10","2021-11","2021-12"],"xaxis":"x","y":[1.092266883243004,0.9940901640837003,0.9471318627212323,0.8913620159829538,0.8436111190968966,0.8211801177897531,0.8370375645674804,0.8842910346379194,0.8533399733006858,0.8424283241086605,1.0564055002791832,0.9515427232931435],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=Normalize XU100.IS<br>ay_y\u0131l=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Normalize XU100.IS","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Normalize XU100.IS","orientation":"v","showlegend":true,"x":["2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10","2021-11","2021-12"],"xaxis":"x","y":[0.9853550728524004,0.9839507826613793,0.930653957771052,0.9347331991490506,0.9499130512296131,0.906981427501019,0.9314564676163074,0.9844188521815395,0.9404841523692815,1.0177878662241966,1.210177826418696,1.2462885654305926],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface ...
